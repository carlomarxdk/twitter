# %% [markdown]
# # Vocabulary analysis notebook

# %%
import pandas as pd
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt

import ast
import nltk, re, pprint
from nltk import word_tokenize

# !pip install wordcloud
from wordcloud import WordCloud

import sys

# %% [markdown]
# Define header for the raw csv data:

# %%
header_list = ["tweetid","userid","user_display_name","user_screen_name","user_reported_location","user_profile_description","user_profile_url","follower_count","following_count","account_creation_date","account_language","tweet_language","tweet_text","tweet_time","tweet_client_name","in_reply_to_tweetid","in_reply_to_userid","quoted_tweet_tweetid","is_retweet","retweet_userid","retweet_tweetid","latitude","longitude","quote_count","reply_count","like_count","retweet_count","hashtags","urls","user_mentions","poll_choices"]
header_dict = {val:i for i,val in enumerate(header_list)}

# %% [markdown]
# Parsing function that loads data into pandas in chunks

# %%
def parse(f,chunksize = 100000, cols = None, test_bool = False, dtype = None):
    lines = 9041*1000
    for i,gm_chunk in enumerate(pd.read_csv("twitter/csv/ira_tweets_csv_hashed.csv",chunksize = chunksize, usecols = cols, dtype = dtype)):
        f(gm_chunk)
        if test_bool:
            print('Done')
            break
        j = i*chunksize/lines
        sys.stdout.write('\r')
        # the exact output you're looking for:
        bar_int = int(j*20+1)
        sys.stdout.write("[%-20s] %d%%" % ('='*bar_int, int(j*100+1)))
        sys.stdout.flush()

# %% [markdown]
# # Vocabulary - words over time (per day)
#
# ### Part 1 - Preprocessing

# %%
cols = ["tweet_language", "tweet_text", "tweet_time"]
global df_tweets_en
df_tweets_en = pd.DataFrame(columns=cols)
follower_dict = defaultdict()
def f(chunk):
    global df_tweets_en
    df_tweets_en = pd.concat([df_tweets_en, chunk[chunk.tweet_language == 'en']])
    
# set test_bool to True to use only a testing subset of data
parse(f, 10000, cols = cols, test_bool = False)
# Out:
# [====================] 100%

# %%
df_tweets_en
# Out:
#         tweet_language                                         tweet_text  \
# 8                   en  As sun and cloud give way to moon and shadow, ...
# 10                  en             Down in the comfort of strangers, I...
# 11                  en                Im laughing more than i should #USA
# 12                  en                       No, I'm not saying I'm sorry
# 32                  en                      Laugh it all off in your face
# 33                  en  It takes courage to make a fool of yourself. –...
# 34                  en      I want to be normal and live with a boyfriend
# 41                  en  « Reverie is when ideas float in our mind with...
# 42                  en  Meet The Democrat’s Next “OBAMA” https://t.co/...
# 43                  en  Kellyanne Conway denies reports of leaking con...
# 50                  en  RT @e933848ee109a3e968bfefb54a785c0426edab39c1...
# 70                  en  Some books should be tasted, some devoured, bu...
# 97                  en  RT @MTVNews: SO. DAMN. CUTE. https://t.co/tiUj...
# 98                  en  RT @Real923LA: A few of our lucky listeners ha...
# 99                  en  RT @ReignOfApril: The Immortal Life of #Henrie...
# 100                 en  RT @RappersIQ: #Papoose Ft. #RemyMa "Black Lov...
# 101                 en  RT @2DopeBoyz: Press play on @knxwledge's WT.P...
# 102                 en  RT @BlackNewsOutlet: Bobby Seale and Huey Newt...
# 103                 en  RT @Herobright2: @UNHumanRights NIGERIA CRIES ...
# 104                 en  RT @74c5eb30de3d6691e150879ee8528463c70b0feaef...
# 105                 en  RT @DJMistaXclusive: Cavs openly question thei...
# 107                 en  #IfAnimalsMadeLaws all parrots would be equal ...
# 108                 en  Mexico City metro now has a penis seat to comb...
# 109                 en  And will replace it with "Magister" Because yo...
# 110                 en  Muslims can't even coexist with Muslims Why do...
# 111                 en  @CapLarryDart @Co_Passenger won't stricter gun...
# 112                 en  And who will determine what exactly is #offens...
# 113                 en  They finally admit they just need everything f...
# 114                 en                                     @BBCWorld yeap
# 115                 en  You know that fat girls who believe in #BodyAc...
# ...                ...                                                ...
# 9041246             en  RT @Steven31015146: 🚨💥🚨💥🚨💥🚨💥BREAKING: NBC Caug...
# 9041247             en  RT @MikeHudema: 200,000 in D.C., 300 cities ar...
# 9041249             en  RT @SheriffClarke: NAACP promotes a self-defea...
# 9041250             en  RT @Bernie2016tv: @YoungPPL4Bernie Simply smas...
# 9041251             en  RT @kevinjohnson510: The Speech That Will Make...
# 9041252             en  RT @gerfingerpoken: Carol Bowne murdered while...
# 9041253             en  RT @ENRICAMALATESTA: Trump administration soug...
# 9041254             en  RT @MsBetsyRoss: MT @JAmy208: Let's remind Con...
# 9041255             en  RT @Heatherhamama: @ScottPresler @MariaBartiro...
# 9041256             en  RT @PrisonPlanet: Tourism and mass uncontrolle...
# 9041257             en  RT @GoldenGateNews: San Francisco police inves...
# 9041274             en  Those who don't believe in magic will never fi...
# 9041275             en  Never let a problem to be solved become more i...
# 9041276             en                      You're killing me, killing me
# 9041279             en  #local #news Peoria hosts Dog Day at spring-tr...
# 9041280             en    National Signing Day 2015 live updates  #sports
# 9041281             en  Bradley, Diamondbacks run away from Rangers  #...
# 9041282             en  Friends of the Phoenix Public Library to donat...
# 9041284             en  Peace is an unstable equilibrium, which can be...
# 9041285             en         If looks kill then you murderin'  – J.Cole
# 9041286             en  To the man who only has a hammer, everything h...
# 9041292             en  @HuskerStan @MichelleyM @NoompsyDahling @WestC...
# 9041293             en                                  @LAmaleCA thanks!
# 9041294             en  RT @fuckmyworklife: #MyVacationGoals to see ho...
# 9041295             en              #ItsBestIfWe learn each other's names
# 9041296             en  RT @TiMiR0: #IfICouldntLie I couldn't tell you...
# 9041303             en  The trouble is not in dying for a friend, but ...
# 9041304             en                     Great souls endure in silence.
# 9041305             en  Learn how to be happy with what you have while...
# 9041306             en    Watch #COINTELPRO 101 (2010) online via DOCcupy
#
#                tweet_time
# 8        2015-02-16 16:19
# 10       2014-07-28 23:02
# 11       2014-07-28 09:24
# 12       2014-08-08 00:43
# 32       2014-08-17 10:46
# 33       2014-12-27 08:54
# 34       2015-03-16 14:33
# 41       2015-01-08 07:45
# 42       2017-06-09 15:39
# 43       2017-06-12 12:39
# 50       2015-08-12 08:10
# 70       2015-03-18 16:04
# 97       2017-01-14 09:53
# 98       2017-03-25 07:54
# 99       2017-04-23 00:24
# 100      2017-01-19 21:54
# 101      2017-01-29 17:37
# 102      2017-04-21 20:01
# 103      2016-10-06 17:34
# 104      2016-02-26 14:54
# 105      2017-04-12 03:40
# 107      2015-07-30 13:04
# 108      2017-04-09 15:45
# 109      2017-04-11 15:52
# 110      2015-12-29 17:58
# 111      2015-11-06 07:29
# 112      2015-11-21 12:33
# 113      2017-02-25 15:05
# 114      2015-06-08 07:34
# 115      2016-05-06 17:25
# ...                   ...
# 9041246  2016-10-14 17:03
# 9041247  2017-05-01 02:01
# 9041249  2016-10-23 18:23
# 9041250  2015-10-12 00:33
# 9041251  2016-10-13 04:54
# 9041252  2016-12-22 02:58
# 9041253  2017-02-26 14:52
# 9041254  2017-03-15 18:03
# 9041255  2017-03-09 16:55
# 9041256  2016-11-20 16:22
# 9041257  2015-04-27 21:33
# 9041274  2015-02-21 09:45
# 9041275  2014-11-10 11:38
# 9041276  2014-11-26 09:35
# 9041279  2015-03-13 16:30
# 9041280  2015-02-04 17:03
# 9041281  2015-04-23 05:52
# 9041282  2016-04-15 03:20
# 9041284  2014-12-23 13:32
# 9041285  2014-12-24 15:58
# 9041286  2015-01-08 08:23
# 9041292  2015-06-03 17:25
# 9041293  2015-10-29 17:37
# 9041294  2016-06-06 13:22
# 9041295  2016-09-04 14:42
# 9041296  2016-09-07 14:59
# 9041303  2015-01-19 10:25
# 9041304  2015-01-19 13:01
# 9041305  2015-01-19 11:43
# 9041306  2016-02-13 18:56
#
# [3261931 rows x 3 columns]

# %% [markdown]
# #### Tweet cleaning

# %%
EMOJIS = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
def remove_emojis(text):
    return EMOJIS.sub(r'', text)

# remove_emojis('RT @Steven31015146: 🚨💥🚨💥🚨💥🚨💥BREAKING: NBC blabla RT bla #MAGA https://t.co/90ElTWQ2XA jep')

# %%
def clean_tweets(tweets):
    # Remove twitter retweet handles (retweets)
    processed_tweets = [re.sub('RT @\w*: ', '', t) for t in tweets]
    # Remove urls
    processed_tweets = [re.sub(' http[s]?:[^\s]+', '', t) for t in processed_tweets]
    # Remove emojis
    processed_tweets = [remove_emojis(t) for t in processed_tweets]
    # Remove hashtags
    processed_tweets = [re.sub('#\w*', '', t) for t in processed_tweets]
    # Remove references to other twitter accounts
    processed_tweets = [re.sub('@\w*', '', t) for t in processed_tweets]
    # Remove other handles
    processed_tweets = [re.sub('[&$]\w*', '', t) for t in processed_tweets]
    
    return processed_tweets

def clean_tweet(tweet):
    # Remove twitter retweet handles (retweets)
    processed_tweet = re.sub('RT @\w*: ', '', tweet)
    # Remove urls
    processed_tweet = re.sub(' http[s]?:?([^\s]*)', '', processed_tweet)
    # Remove emojis
    processed_tweet = remove_emojis(processed_tweet)
    # Remove hashtags
    processed_tweet = re.sub('#\w*', '', processed_tweet)
    # Remove references to other twitter accounts
    processed_tweet = re.sub('@\w*', '', processed_tweet)
    # Remove other handles
    processed_tweet = re.sub('[&$]\w*', '', processed_tweet)
    
    return processed_tweet

# %%
df_tweets_en['clean_tweet'] = clean_tweets(df_tweets_en.tweet_text)
df_tweets_en
# Out:
#         tweet_language                                         tweet_text  \
# 8                   en  As sun and cloud give way to moon and shadow, ...
# 10                  en             Down in the comfort of strangers, I...
# 11                  en                Im laughing more than i should #USA
# 12                  en                       No, I'm not saying I'm sorry
# 32                  en                      Laugh it all off in your face
# 33                  en  It takes courage to make a fool of yourself. –...
# 34                  en      I want to be normal and live with a boyfriend
# 41                  en  « Reverie is when ideas float in our mind with...
# 42                  en  Meet The Democrat’s Next “OBAMA” https://t.co/...
# 43                  en  Kellyanne Conway denies reports of leaking con...
# 50                  en  RT @e933848ee109a3e968bfefb54a785c0426edab39c1...
# 70                  en  Some books should be tasted, some devoured, bu...
# 97                  en  RT @MTVNews: SO. DAMN. CUTE. https://t.co/tiUj...
# 98                  en  RT @Real923LA: A few of our lucky listeners ha...
# 99                  en  RT @ReignOfApril: The Immortal Life of #Henrie...
# 100                 en  RT @RappersIQ: #Papoose Ft. #RemyMa "Black Lov...
# 101                 en  RT @2DopeBoyz: Press play on @knxwledge's WT.P...
# 102                 en  RT @BlackNewsOutlet: Bobby Seale and Huey Newt...
# 103                 en  RT @Herobright2: @UNHumanRights NIGERIA CRIES ...
# 104                 en  RT @74c5eb30de3d6691e150879ee8528463c70b0feaef...
# 105                 en  RT @DJMistaXclusive: Cavs openly question thei...
# 107                 en  #IfAnimalsMadeLaws all parrots would be equal ...
# 108                 en  Mexico City metro now has a penis seat to comb...
# 109                 en  And will replace it with "Magister" Because yo...
# 110                 en  Muslims can't even coexist with Muslims Why do...
# 111                 en  @CapLarryDart @Co_Passenger won't stricter gun...
# 112                 en  And who will determine what exactly is #offens...
# 113                 en  They finally admit they just need everything f...
# 114                 en                                     @BBCWorld yeap
# 115                 en  You know that fat girls who believe in #BodyAc...
# ...                ...                                                ...
# 9041246             en  RT @Steven31015146: 🚨💥🚨💥🚨💥🚨💥BREAKING: NBC Caug...
# 9041247             en  RT @MikeHudema: 200,000 in D.C., 300 cities ar...
# 9041249             en  RT @SheriffClarke: NAACP promotes a self-defea...
# 9041250             en  RT @Bernie2016tv: @YoungPPL4Bernie Simply smas...
# 9041251             en  RT @kevinjohnson510: The Speech That Will Make...
# 9041252             en  RT @gerfingerpoken: Carol Bowne murdered while...
# 9041253             en  RT @ENRICAMALATESTA: Trump administration soug...
# 9041254             en  RT @MsBetsyRoss: MT @JAmy208: Let's remind Con...
# 9041255             en  RT @Heatherhamama: @ScottPresler @MariaBartiro...
# 9041256             en  RT @PrisonPlanet: Tourism and mass uncontrolle...
# 9041257             en  RT @GoldenGateNews: San Francisco police inves...
# 9041274             en  Those who don't believe in magic will never fi...
# 9041275             en  Never let a problem to be solved become more i...
# 9041276             en                      You're killing me, killing me
# 9041279             en  #local #news Peoria hosts Dog Day at spring-tr...
# 9041280             en    National Signing Day 2015 live updates  #sports
# 9041281             en  Bradley, Diamondbacks run away from Rangers  #...
# 9041282             en  Friends of the Phoenix Public Library to donat...
# 9041284             en  Peace is an unstable equilibrium, which can be...
# 9041285             en         If looks kill then you murderin'  – J.Cole
# 9041286             en  To the man who only has a hammer, everything h...
# 9041292             en  @HuskerStan @MichelleyM @NoompsyDahling @WestC...
# 9041293             en                                  @LAmaleCA thanks!
# 9041294             en  RT @fuckmyworklife: #MyVacationGoals to see ho...
# 9041295             en              #ItsBestIfWe learn each other's names
# 9041296             en  RT @TiMiR0: #IfICouldntLie I couldn't tell you...
# 9041303             en  The trouble is not in dying for a friend, but ...
# 9041304             en                     Great souls endure in silence.
# 9041305             en  Learn how to be happy with what you have while...
# 9041306             en    Watch #COINTELPRO 101 (2010) online via DOCcupy
#
#                tweet_time                                        clean_tweet
# 8        2015-02-16 16:19  As sun and cloud give way to moon and shadow, ...
# 10       2014-07-28 23:02             Down in the comfort of strangers, I...
# 11       2014-07-28 09:24                    Im laughing more than i should
# 12       2014-08-08 00:43                       No, I'm not saying I'm sorry
# 32       2014-08-17 10:46                      Laugh it all off in your face
# 33       2014-12-27 08:54  It takes courage to make a fool of yourself. –...
# 34       2015-03-16 14:33      I want to be normal and live with a boyfriend
# 41       2015-01-08 07:45  « Reverie is when ideas float in our mind with...
# 42       2017-06-09 15:39                   Meet The Democrat’s Next “OBAMA”
# 43       2017-06-12 12:39  Kellyanne Conway denies reports of leaking con...
# 50       2015-08-12 08:10  Saw it several days ago during a trip and that...
# 70       2015-03-18 16:04  Some books should be tasted, some devoured, bu...
# 97       2017-01-14 09:53                                    SO. DAMN. CUTE.
# 98       2017-03-25 07:54  A few of our lucky listeners hanging out at th...
# 99       2017-04-23 00:24  The Immortal Life of  starring  and  starts NO...
# 100      2017-01-19 21:54                         Ft.  "Black Love"
# 101      2017-01-29 17:37  Press play on 's WT.PRT10.8 project; with flip...
# 102      2017-04-21 20:01  Bobby Seale and Huey Newton, the founders of t...
# 103      2016-10-06 17:34     NIGERIA CRIES OUT: "AVENGERS HAVE FINISHED US"
# 104      2016-02-26 14:54   You seen the video of The Police Tellin 's ki...
# 105      2017-04-12 03:40  Cavs openly question their true nature as seas...
# 107      2015-07-30 13:04     all parrots would be equal from the beginning
# 108      2017-04-09 15:45  Mexico City metro now has a penis seat to comb...
# 109      2017-04-11 15:52  And will replace it with "Magister" Because yo...
# 110      2015-12-29 17:58  Muslims can't even coexist with Muslims Why do...
# 111      2015-11-06 07:29    won't stricter gun control change the situat...
# 112      2015-11-21 12:33           And who will determine what exactly is ?
# 113      2017-02-25 15:05  They finally admit they just need everything f...
# 114      2015-06-08 07:34                                               yeap
# 115      2016-05-06 17:25  You know that fat girls who believe in  usuall...
# ...                   ...                                                ...
# 9041246  2016-10-14 17:03  BREAKING: NBC Caught in MASSIVE Lie About Leak...
# 9041247  2017-05-01 02:01  200,000 in D.C., 300 cities around the world, ...
# 9041249  2016-10-23 18:23  NAACP promotes a self-defeating cultural dysfu...
# 9041250  2015-10-12 00:33                 Simply smashing! Thanks!  prwd by
# 9041251  2016-10-13 04:54  The Speech That Will Make Donald Trump Preside...
# 9041252  2016-12-22 02:58  Carol Bowne murdered while waiting 4 backgroun...
# 9041253  2017-02-26 14:52  Trump administration sought to enlist intellig...
# 9041254  2017-03-15 18:03  MT : Let's remind Congress who's in charge. We...
# 9041255  2017-03-09 16:55                                    the real heroes
# 9041256  2016-11-20 16:22  Tourism and mass uncontrolled immigration are ...
# 9041257  2015-04-27 21:33     San Francisco police investigate shooting at
# 9041274  2015-02-21 09:45  Those who don't believe in magic will never fi...
# 9041275  2014-11-10 11:38  Never let a problem to be solved become more i...
# 9041276  2014-11-26 09:35                      You're killing me, killing me
# 9041279  2015-03-13 16:30    Peoria hosts Dog Day at spring-training ball...
# 9041280  2015-02-04 17:03           National Signing Day 2015 live updates
# 9041281  2015-04-23 05:52      Bradley, Diamondbacks run away from Rangers
# 9041282  2016-04-15 03:20  Friends of the Phoenix Public Library to donat...
# 9041284  2014-12-23 13:32  Peace is an unstable equilibrium, which can be...
# 9041285  2014-12-24 15:58         If looks kill then you murderin'  – J.Cole
# 9041286  2015-01-08 08:23  To the man who only has a hammer, everything h...
# 9041292  2015-06-03 17:25                                    oooh thank you!
# 9041293  2015-10-29 17:37                                            thanks!
# 9041294  2016-06-06 13:22   to see how many Americans I can shock when I ...
# 9041295  2016-09-04 14:42                           learn each other's names
# 9041296  2016-09-07 14:59         I couldn't tell you all dogs go to heaven.
# 9041303  2015-01-19 10:25  The trouble is not in dying for a friend, but ...
# 9041304  2015-01-19 13:01                     Great souls endure in silence.
# 9041305  2015-01-19 11:43  Learn how to be happy with what you have while...
# 9041306  2016-02-13 18:56               Watch  101 (2010) online via DOCcupy
#
# [3261931 rows x 4 columns]

# %% [markdown]
# #### Tweet tokenization

# %%
import nltk
from nltk.corpus import stopwords

stopwords_eng = stopwords.words('english')
stopwords_eng += ['would', 'http', 'https']

wnl = nltk.WordNetLemmatizer()

def tokenize_tweet(tweet, lemmatize=False):
    return set(tokenize_tweet_to_list(tweet, lemmatize))

def tokenize_tweet_to_list(tweet, lemmatize=False):
    pattern = '\w+'
    tokenized = nltk.regexp_tokenize(tweet, pattern)
    if lemmatize:
        content = [wnl.lemmatize(w.lower()) for w in tokenized if w.lower() not in stopwords_eng and len(w)>2 and not w.isdigit()]
    else:
        content = [w.lower() for w in tokenized if w.lower() not in stopwords_eng and len(w)>2 and not w.isdigit()]
    return content

# %%
df_tweets_en['tokens'] = [tokenize_tweet(tweet, lemmatize=True) for tweet in df_tweets_en.clean_tweet]
df_tweets_en.iloc[0]
# Out:
# tweet_language                                                   en
# tweet_text        As sun and cloud give way to moon and shadow, ...
# tweet_time                                         2015-02-16 16:19
# clean_tweet       As sun and cloud give way to moon and shadow, ...
# tokens            {way, world, make, moon, rhythm, faith, sun, s...
# Name: 8, dtype: object

# %% [markdown]
# Group tweets by month:

# %%
df_tweets_en['tweet_time'] = pd.to_datetime(df_tweets_en.tweet_time)
# Group tweets by month
g = df_tweets_en.groupby(pd.Grouper(key='tweet_time',freq='M'))

# join tokens of tweets from one month to list
df_monthly_grouped_tweets = g.tokens.apply(lambda x: list(x)).to_frame(name="tweet_token_list")
df_monthly_grouped_tweets
# Out:
#                                              tweet_token_list
# tweet_time
# 2009-11-30  [{correctly, keep, trying, swimming, lol, retw...
# 2009-12-31                                                 []
# 2010-01-31            [{itunes, album, reminder, link, post}]
# 2010-02-28  [{chile60th, see, patagonia, orbit, ever, day,...
# 2010-03-31  [{dam, alp, southern, zealand, big, new, man, ...
# 2010-04-30             [{world, 1f1dkq, hello, com, twitpic}]
# 2010-05-31                               [{comic, way, best}]
# 2010-06-30  [{enjoy, cure, save, interval, birth, death}, ...
# 2010-07-31  [{buddy, year, whiz, quinn, sullivan, guitar, ...
# 2010-08-31  [{think, workday, two, need, choice, night, le...
# 2010-09-30  [{getting, ful, job, chance, giving, good, edu...
# 2010-10-31  [{level}, {novosibirsk, headache, love, say, m...
# 2010-11-30                                 [{addicted, help}]
# 2010-12-31                                                 []
# 2011-01-31                                   [{famous, shit}]
# 2011-02-28                                                 []
# 2011-03-31                                                 []
# 2011-04-30  [{best, beauty_diorxxx, follower, get, use, ba...
# 2011-05-31                                                 []
# 2011-06-30                                                 []
# 2011-07-31                    [{something, see, say, moscow}]
# 2011-08-31                                                 []
# 2011-09-30  [{noinstruments, real, sound, good, caalamus},...
# 2011-10-31                               [{angry, badminton}]
# 2011-11-30                               [{krishna, missing}]
# 2011-12-31                                                 []
# 2012-01-31                                [{give, man, fuck}]
# 2012-02-29                                                 []
# 2012-03-31                                                 []
# 2012-04-30  [{posted, photo}, {free, eusing, cutter, mp3},...
# ...                                                       ...
# 2015-12-31  [{waste, authority, fine, property, business, ...
# 2016-01-31  [{delivery, tosa, alert, worker, fire, paper, ...
# 2016-02-29  [{fighter}, {drink, nalang, bihira, vape, dont...
# 2016-03-31  [{leap, birthday, adult, celebrate, day, rare,...
# 2016-04-30  [{wtae, news, wendy, black, criminal, job, bra...
# 2016-05-31  [{prince, fired, day, tribute, anchor, sport, ...
# 2016-06-30  [{stay, tip, water, summer, safe}, {kept, goal...
# 2016-07-31  [{willing, explosive, wanted, say, use, prosec...
# 2016-08-31  [{back, sander, supporter, clinton, urging}, {...
# 2016-09-30  [{denied, court, gun, pot, cardholder, appeal,...
# 2016-10-31  [{woman, black, police, men, unarmed, killed},...
# 2016-11-30  [{outted, hillary, barack, obama, lied, breaki...
# 2016-12-31  [{cub, pick, commerce, owner, deputy, secretar...
# 2017-01-31  [{gop, year, erase, new, congress, get, obama,...
# 2017-02-28  [{new, culture, change, goal, cat}, {muslim, s...
# 2017-03-31  [{president, address, expectation, congress, f...
# 2017-04-30  [{tao, tonight, walk, hit, la, in, plug, openb...
# 2017-05-31  [{maple, loyalty, may, ivana, marla, unavailab...
# 2017-06-30  [{nearly, losing, southern, illinois, employee...
# 2017-07-31  [{police, fort, group, worth, chief, take, con...
# 2017-08-31  [{deepstate, 3lawsuits, 4info, slam, watch, do...
# 2017-09-30  [{draw, expected, repeal, program, fire, busin...
# 2017-10-31  [{know, need, wrote}, {rico, praise, mayor, sl...
# 2017-11-30  [{break, afraid}, {saipov, sayfullo, admin, ne...
# 2017-12-31  [{tree, ceremony, president, drive, crazy, lig...
# 2018-01-31  [{aunt, news, year, priceless, day, barrington...
# 2018-02-28  [{leader, true, teacher, inspiration}, {best, ...
# 2018-03-31  [{see, cnn}, {afraid, afra, job, shooter, cop,...
# 2018-04-30  [{april, voter, day, every, fool, trump}, {kno...
# 2018-05-31  [{period, congressional, idea, call, tryout, p...
#
# [103 rows x 1 columns]

# %% [markdown]
# Functions to calculate TF-IDF:

# %%
def idf(w, docs):
    return np.log( (len(docs)) / (1 + sum([w in doc for doc in docs])) )

def tfidf(docs):
    if len(docs) == 0:
        return dict()
    tokens = [token for doc in docs for token in doc]
    f = nltk.FreqDist(tokens)
    tfidf = {w:f[w]*idf(w, docs) for w in f.keys()}
    return tfidf

# %% [markdown]
# ## Part 2 - Create and save wordclouds for each month based on calculated TF-IDF

# %%
# Generate a word cloud image
import os
from os import path
from PIL import Image
#define path for a mask
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()
#upload mask for thre cloud
twitter_mask = np.array(Image.open(path.join(d, "twitter-logo.jpg")))

def save_wordcloud(date, tf_idf, num_tweets):
    wordcloud = WordCloud(background_color="white", max_words=150, mask = twitter_mask).generate_from_frequencies(tf_idf)

    # Display the generated image:
    plt.figure(figsize=(10, 10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title("Word-cloud based on TF-IDF of %d tweets (%s)" % (num_tweets, date))
    plt.axis("off")
    reverse_date = date.split("-")
    plt.savefig("vocab-wordcloud-lemmatized/wordcloud-%s-%s.png" % (reverse_date[1], reverse_date[0]))
    plt.close()
#     plt.show()

# %%
tfidf(df_monthly_grouped_tweets.iloc[0].tweet_token_list)
# Out:
# {'correctly': -0.6931471805599453,
#  'keep': -0.6931471805599453,
#  'trying': -0.6931471805599453,
#  'swimming': -0.6931471805599453,
#  'lol': -0.6931471805599453,
#  'retweet': -0.6931471805599453}

# %% [markdown]
# #### Save only wordclouds having more than 20 tokens (words) in a month
# ! Note that the following code block can take a while to finish (few hours at least) !

# %%
# Save monthly wordclouds to file
for row in df_monthly_grouped_tweets.iterrows():
    date = "%d-%d" % (row[0].month, row[0].year)
    tf_idf = tfidf(row[1].tweet_token_list)
    num_tweets = len(row[1].tweet_token_list)
    if len(tf_idf) > 20:
        print('working on %s' % date)
        save_wordcloud(date, tf_idf, num_tweets)
# Out:
# working on 12-2012
# working on 1-2013
# working on 4-2013
# working on 5-2013
# working on 6-2013
# working on 7-2013
# working on 8-2013
# working on 9-2013
# working on 10-2013
# working on 11-2013
# working on 12-2013
# working on 1-2014
# working on 2-2014
# working on 3-2014
# working on 4-2014
# working on 5-2014
# working on 6-2014
# working on 7-2014
# working on 8-2014
# working on 9-2014
# working on 10-2014
# working on 11-2014
# working on 12-2014
# working on 1-2015
# working on 2-2015
# working on 3-2015
# working on 4-2015
# working on 5-2015
# working on 6-2015
# working on 7-2015
# working on 8-2015
# working on 9-2015
# working on 10-2015
# working on 11-2015
# working on 12-2015
# working on 1-2016
# working on 2-2016
# working on 3-2016
# working on 4-2016
# working on 5-2016
# working on 6-2016
# working on 7-2016
# working on 8-2016
# working on 9-2016
# working on 10-2016
# working on 11-2016
# working on 12-2016
# working on 1-2017
# working on 2-2017
# working on 3-2017
# working on 4-2017
# working on 5-2017
# working on 6-2017
# working on 7-2017
# working on 8-2017
# working on 9-2017
# working on 10-2017
# working on 11-2017
# working on 12-2017
# working on 1-2018
# working on 2-2018
# working on 3-2018
# working on 4-2018
# working on 5-2018

# %% [markdown]
# ## Part 3 - Groupping tweets

# %% [markdown]
# #### Group tokens by day and save to file
# In case of exceeding memory limit, we will later load the data from text file directly.

# %%
df_monthly_grouped_tweets['tfidf'] = [tfidf(tweet_list) for tweet_list in df_monthly_grouped_tweets.tweet_token_list]

# %%
df_tweets_en['tweet_time'] = pd.to_datetime(df_tweets_en.tweet_time)
# Group tweets by day
g = df_tweets_en.groupby(pd.Grouper(key='tweet_time',freq='D'))

# join tokens of tweets from one day to list
df_daily_grouped_tokens = g.tokens.apply(lambda x: [inner for outer in x for inner in outer])
df_daily_grouped_tokens

# %%
# Save daily grouped tokens
df_daily_grouped_tokens.to_csv('daily_en_tokens.csv')

# %% [markdown]
# #### Group tokens by month and save to file

# %%
df_daily_tokens = pd.read_csv('daily_en_tokens.csv', names=['day','tokens'])
df_daily_tokens = df_daily_tokens[df_daily_tokens.tokens != '[]']
df_daily_tokens['day'] = pd.to_datetime(df_daily_tokens.day)
df_daily_tokens

# %%
# Group tweets by month
gm = df_daily_tokens.groupby(pd.Grouper(key='day',freq='M'))

# join tokens of tweets from one day to list
df_monthly_grouped_tokens = gm.tokens.apply(lambda x: list(x))
df_monthly_grouped_tokens

# %% [markdown]
# To use the list of tokens, we first need to change it from string to real list. "[a, b]" -> [a, b]

# %%
def evaluate(tokens_list):
    return [ast.literal_eval(tl) for tl in tokens_list]
df_monthly_grouped_tokens = df_monthly_grouped_tokens.apply(evaluate)

# %%
df_monthly_grouped_tokens

# %%
# Save monthly grouped token lists
df_monthly_grouped_tokens.to_csv('monthly_en_token_lists.csv')

# %% [markdown]
# ## Part 4 - TF-IDF for daily tweets grouped by month

# %%
df_monthly_tokens = pd.read_csv('monthly_en_token_lists.csv', names=['date','token_lists'])
# df_daily_tokens.tokens = [ast.literal_eval("%r" % tokens) for tokens in df_daily_tokens.tokens]
# df_monthly_tokens = df_monthly_tokens[df_daily_tokens.tokens != '[]']
df_monthly_tokens['date'] = pd.to_datetime(df_monthly_tokens.date)
df_monthly_tokens = df_monthly_tokens.set_index('date')
# df_monthly_tokens.token_lists = df_monthly_tokens.token_lists.apply(evaluate)
df_monthly_tokens

# %% [markdown]
# Get list of all tokens throughout the dataset:

# %%
all_tokens = list()
i = 0
for row in df_monthly_tokens.token_lists:
    all_tokens += tokenize_tweet_to_list(row)
len(all_tokens)

# %% [markdown]
# Lemmatize tokens:

# %%
# Lemmatize tokens
wnl = nltk.WordNetLemmatizer()
all_tokens_lemmatized = [wnl.lemmatize(t) for t in all_tokens]
len(all_tokens_lemmatized)

# %%
all_most_common = nltk.FreqDist(all_tokens).most_common(150)
all_most_common

# %% [markdown]
# Save the monthly freaquencies for the 150 most common tokens (words):

# %%
top_words = [row[0] for row in all_most_common]
len(top_words)

# %%
wnl = nltk.WordNetLemmatizer()
# Save monthly frequencies of the top words to file
with open('monthly_top_words_frequencies.csv', 'w') as the_file:
    the_file.write('date,' + ','.join(top_words) + '\n')
    for row in df_monthly_tokens.iterrows():
        tokens_lemmatized = [wnl.lemmatize(t) for t in tokenize_tweet_to_list(row[1].token_lists)]
        freq_dist = dict(nltk.FreqDist(tokens_lemmatized))
        
        counts = list()
        for word in top_words:
            if word in freq_dist:
                counts.append("%d" % freq_dist[word])
            else:
                counts.append("0")
        
        the_file.write("%d-%d" % (row[0].year, row[0].month) + ',' + ','.join(counts) + '\n')

# %% [markdown]
# ## Part 5 - Plot monthly summary of vocabulary based on TF-IDF

# %%
import datetime

# %%
df_monthly_top_words_freq = pd.read_csv('monthly_top_words_frequencies.csv')
df_monthly_top_words_freq['date'] = pd.to_datetime(df_monthly_top_words_freq.date)
df_monthly_top_words_freq = df_monthly_top_words_freq.set_index('date')
df_monthly_top_words_freq = df_monthly_top_words_freq.loc[datetime.date(year=2014,month=1,day=1):datetime.date(year=2018,month=9,day=1)]
df_monthly_top_words_freq.index = df_monthly_top_words_freq.index.strftime('%b-%y')

# %%
# ad-hoc join counts for words "america" and "american"
df_monthly_top_words_freq["america"] = df_monthly_top_words_freq["america"].add(df_monthly_top_words_freq["american"])
df_monthly_top_words_freq.drop(['american'], axis=1, inplace=True)

# %%
import plotly.plotly as py
import cufflinks as cf
import pandas as pd
import numpy as np
import plotly

# %%
plotly.tools.set_credentials_file(username='s180012', api_key='ARWPjbRNuBBRc8wpdG9V')

labels = list(df_monthly_top_words_freq)

df_monthly_top_words_freq.iplot(kind='bar', barmode='stack', fill=True, y=labels[0:100],  xTitle='Date', yTitle='Number of tweets', colorscale='spectral')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~s180012/18.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### Selecting words for later manual filtering

# %%
word_mean = {}
for col in list(df_monthly_top_words_freq)[:100]:
    word_mean[col] = {"max": df_monthly_top_words_freq[col].max(), "mean": df_monthly_top_words_freq[col].mean()}

word_mean

# %%
[(word, word_mean[word]) for word in word_mean if word_mean[word]["max"] > 5000]

# %% [markdown]
# **Selected words:** america, breaking, hillary, president, obama, people, new, trump
